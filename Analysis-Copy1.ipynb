# %%
import re
import pandas as pd

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
f=open("snail1.txt","r",encoding="utf-8")

# %%
data=f.read()

# %%
data
# Out:
# '11/07/2022, 12:25\u202fpm - Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. Tap to learn more.\n11/07/2022, 12:25\u202fpm - Nagaraj Kaddipudi: Plz send me\n11/07/2022, 12:27\u202fpm - Nagaraj Kaddipudi: My status 3rd video download and send me\n11/07/2022, 12:28\u202fpm - Abhi: 20 best medicine?\n11/07/2022, 12:29\u202fpm - Nagaraj Kaddipudi: 👍\n11/07/2022, 12:29\u202fpm - Abhi: <Media omitted>\n11/07/2022, 12:32\u202fpm - Nagaraj Kaddipudi: 👍\n18/07/2022, 6:01\u202fpm - Abhi: Appaji think ennara thogand barri\n18/07/2022, 6:01\u202fpm - Abhi: Hotti hasthav\n21/07/2022, 5:14\u202fpm - Abhi: This message was deleted\n22/07/2022, 11:15\u202fam - Abhi: <Media omitted>\n29/07/2022, 11:05\u202fam - Nagaraj Kaddipudi: Shop now on Meesho!\nhttps://www.meesho.com/s/p/54ab1?utm_source=s\n29/07/2022, 11:13\u202fam - Nagaraj Kaddipudi: Shop now on Meesho!\nhttps://www.meesho.com/s/p/1emhj2?utm_source=s\n29/07/2022, 11:14\u202fam - Nagaraj Kaddipudi: Shop now on Meesho!\nhttps://www.meesho.com/s/p/20ywgq?utm_source=s\n29/07/2022, 11:20\u202fam - Nagaraj Kaddipudi: Shop now on Meesho!\nhttps://www.meesho.com/s/p/1tnjbp?utm_source=s\n31/07/2022, 6:26\u202fpm - Nagaraj Kaddipudi: https://www.amazon.in/Plus-Arogya-Acupressure-Acupuncture-Protection/dp/B078PJCNBZ/ref=asc_df_B078PJCNBZ/?tag=googleshopmob-21&linkCode=df0&hvadid=397050205873&hvpos=&hvnetw=g&hvrand=15966072829977232666&hvpone=&hvptwo=&hvqmt=&hvdev=m&hvdvcmdl=&hvlocint=&hvlocphy=9299674&hvtargid=pla-836280870659&psc=1&ext_vrnc=hi\n02/08/2022, 11:11\u202fam - Abhi: <Media omitted>\n02/08/2022, 11:11\u202fam - Abhi: Please join #HarGharTiranga campaign Change your dp to Indian tricolour\n02/08/2022, 4:28\u202fpm - Nagaraj Kaddipudi: <Media omitted>\n02/08/2022, 7:30\u202fpm - Nagaraj Kaddipudi: <Media omitted>\n02/08/2022, 7:30\u202fpm - Nagaraj Kaddipudi: <Media omitted>\n03/08/2022, 10:02\u202fam - Abhi: +919900191293\n03/08/2022, 10:02\u202fam - Abhi: Delivery boy\n03/08/2022, 11:20\u202fam - Nagaraj Kaddipudi: <Media omitted>\n03/08/2022, 11:20\u202fam - Nagaraj Kaddipudi: <Media omitted>\n03/08/2022, 11:20\u202fam - Nagaraj Kaddipudi: <Media omitted>\n03/08/2022, 11:20\u202fam - Nagaraj Kaddipudi: <Media omitted>\n03/08/2022, 11:20\u202fam - Nagaraj Kaddipudi: <Media omitted>\n03/08/2022, 11:20\u202fam - Nagaraj Kaddipudi: <Media omitted>\n03/08/2022, 11:20\u202fam - Nagaraj Kaddipudi: <Media omitted>\n03/08/2022, 11:20\u202fam - Nagaraj Kaddipudi: <Media omitted>\n03/08/2022, 11:20\u202fam - Nagaraj Kaddipudi: <Media omitted>\n03/08/2022, 11:56\u202fam - Abhi: 9535309521\n03/08/2022, 11:56\u202fam - Abhi: Deepa tailor\n03/08/2022, 4:47\u202fpm - Nagaraj Kaddipudi: Dear Candidate \n\n\n\nWe are Inviting you to the job portal \n\n\n\nTo register with Ameyyajobs.com as a Candidates and get a Job \nGet a call from the Direct Compny (Consltancy is not Allowed)\nMany Companies are looking for Skilled Candidates like you. \n\n\n\nFill in all the information on your (Profile page and My Resume Page)\nAnd upload best Profile Pitcher so that Company can See you.\n\n \n\nIf Getting difficult to create Resume then its very Easy to create (Just One Click)\n\n\n\nBenefits with ameyyajobs.com \n\n\na.Free Registration \n\nb.You can Apply for jobs \n\nc.The company can Directly Call you \n\nd.Get new Job Alerts \n\ne.Easy to Use \n\nf.Easy to Create Resume \n\ng.Best Support from Ameyya Team \n\nh.Affordable fees\n\n\n\nHow to get a job \n\n\n\nOption A\n\n\nRegister as a Candidate >  Search best Employer or job  >  See Requirement  > Apply for job\n\n\n\nOption B \n\n\nCreate best Profile > Select Urgent Package >  Get hired Direct from Company\n\n\n\n\nSupport \n8884476667\n\n\nRegards \nAmeyyajobs.com\n\n03/08/2022, 4:47\u202fpm - Nagaraj Kaddipudi: <Media omitted>\n03/08/2022, 4:47\u202fpm - Nagaraj Kaddipudi: <Media omitted>\n04/08/2022, 8:16\u202fam - Nagaraj Kaddipudi: <Media omitted>\n05/08/2022, 1:53\u202fpm - A ...

# %%
pattern=r"\d{2}/\d{2}/\d{4}, \d{2}:\d{2}\s?[ap]m - "

# %%
messages = re.split(pattern,data)
messages
# Out:
# ['',
#  'Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. Tap to learn more.\n',
#  'Nagaraj Kaddipudi: Plz send me\n',
#  'Nagaraj Kaddipudi: My status 3rd video download and send me\n',
#  'Abhi: 20 best medicine?\n',
#  'Nagaraj Kaddipudi: 👍\n',
#  'Abhi: <Media omitted>\n',
#  'Nagaraj Kaddipudi: 👍\n18/07/2022, 6:01\u202fpm - Abhi: Appaji think ennara thogand barri\n18/07/2022, 6:01\u202fpm - Abhi: Hotti hasthav\n21/07/2022, 5:14\u202fpm - Abhi: This message was deleted\n',
#  'Abhi: <Media omitted>\n',
#  'Nagaraj Kaddipudi: Shop now on Meesho!\nhttps://www.meesho.com/s/p/54ab1?utm_source=s\n',
#  'Nagaraj Kaddipudi: Shop now on Meesho!\nhttps://www.meesho.com/s/p/1emhj2?utm_source=s\n',
#  'Nagaraj Kaddipudi: Shop now on Meesho!\nhttps://www.meesho.com/s/p/20ywgq?utm_source=s\n',
#  'Nagaraj Kaddipudi: Shop now on Meesho!\nhttps://www.meesho.com/s/p/1tnjbp?utm_source=s\n31/07/2022, 6:26\u202fpm - Nagaraj Kaddipudi: https://www.amazon.in/Plus-Arogya-Acupressure-Acupuncture-Protection/dp/B078PJCNBZ/ref=asc_df_B078PJCNBZ/?tag=googleshopmob-21&linkCode=df0&hvadid=397050205873&hvpos=&hvnetw=g&hvrand=15966072829977232666&hvpone=&hvptwo=&hvqmt=&hvdev=m&hvdvcmdl=&hvlocint=&hvlocphy=9299674&hvtargid=pla-836280870659&psc=1&ext_vrnc=hi\n',
#  'Abhi: <Media omitted>\n',
#  'Abhi: Please join #HarGharTiranga campaign Change your dp to Indian tricolour\n02/08/2022, 4:28\u202fpm - Nagaraj Kaddipudi: <Media omitted>\n02/08/2022, 7:30\u202fpm - Nagaraj Kaddipudi: <Media omitted>\n02/08/2022, 7:30\u202fpm - Nagaraj Kaddipudi: <Media omitted>\n',
#  'Abhi: +919900191293\n',
#  'Abhi: Delivery boy\n',
#  'Nagaraj Kaddipudi: <Media omitted>\n',
#  'Nagaraj Kaddipudi: <Media omitted>\n',
#  'Nagaraj Kaddipudi: <Media omitted>\n',
#  'Nagaraj Kaddipudi: <Media omitted>\n',
#  'Nagaraj Kaddipudi: <Media omitted>\n',
#  'Nagaraj Kaddipudi: <Media omitted>\n',
#  'Nagaraj Kaddipudi: <Media omitted>\n',
#  'Nagaraj Kaddipudi: <Media omitted>\n',
#  'Nagaraj Kaddipudi: <Media omitted>\n',
#  'Abhi: 9535309521\n',
#  'Abhi: Deepa tailor\n03/08/2022, 4:47\u202fpm - Nagaraj Kaddipudi: Dear Candidate \n\n\n\nWe are Inviting you to the job portal \n\n\n\nTo register with Ameyyajobs.com as a Candidates and get a Job \nGet a call from the Direct Compny (Consltancy is not Allowed)\nMany Companies are looking for Skilled Candidates like you. \n\n\n\nFill in all the information on your (Profile page and My Resume Page)\nAnd upload best Profile Pitcher so that Company can See you.\n\n \n\nIf Getting difficult to create Resume then its very Easy to create (Just One Click)\n\n\n\nBenefits with ameyyajobs.com \n\n\na.Free Registration \n\nb.You can Apply for jobs \n\nc.The company can Directly Call you \n\nd.Get new Job Alerts \n\ne.Easy to Use \n\nf.Easy to Create Resume \n\ng.Best Support from Ameyya Team \n\nh.Affordable fees\n\n\n\nHow to get a job \n\n\n\nOption A\n\n\nRegister as a Candidate >  Search best Employer or job  >  See Requirement  > Apply for job\n\n\n\nOption B \n\n\nCreate best Profile > Select Urgent Package >  Get hired Direct from Company\n\n\n\n\nSupport \n8884476667\n\n\nRegards \nAmeyyajobs.com\n\n03/08/2022, 4:47\u202fpm - Nagaraj Kaddipudi: <Media omitted>\n03/08/2022, 4:47\u202fpm - Nagaraj Kaddipudi: <Media omitted>\
#  'Abhi: Yaad urru ast Mandi eradh\n',
#  'Nagaraj Kaddipudi: 20ಲಕ್ಷದ ಮೇಲೆ ಇದೆ\n',
#  'Abhi: Yaa urru?\n',
#  'Nagaraj Kaddipudi: ಕರ್ನಾಟಕ ಮಹಾರಾಷ್ಟ ಮಂದಿ\n',
#  'Abhi: Ok\n04/01/2023, 1:56\u202fpm - Abhi: Missed video call\n06/01/2023, 3:11\u202fpm - Abhi: Missed video call\n06/01/2023, 3:11\u202fpm - Abhi: Missed voice call\n14/01/2023, 9:04\u202fpm - Nagaraj Kaddipudi: <Media omitted>\n14/01/2023, 9:05\u202fpm - Abhi: 👍\n',
#  'Nagaraj Kaddipudi: <Media omitted>\n',
#  'Abhi: +919110430409 shivukumar\n',
#  'Abhi: This message was deleted\n',
#  'Abhi: This message was deleted\n',
#  'Abhi: This message was deleted\n',
#  'Abhi: This message was deleted\n',
#  'Abhi: This message was deleted\n',
#  'Abhi: <Media omitted>\n',
#  'Abhi: <Media omitted>\n',
#  'Abhi: <Media omitted>\n',
#  'Abhi: <Media omitted>\n',
#  'Abhi: <Media omitted>\n',
#  'Abhi: <Media omitted>\n24/02/2023, 4:18\u202fpm - Nagaraj Kaddipudi: <Media omitted>\n03/03/2023, 8:00\u202fpm - Abhi: +919448247422\n03/03/2023, 8:00\u202fpm - Abhi: Ee number ge phn hachhrii\n03/03/2023, 8:00\u202fpm - Abhi: Akka bagge kelatgara\n03/03/2023, 8:00\u202fpm - Abhi: Missed voice call\n22/03/2023, 8:20\u202fpm - Nagaraj Kaddipudi: <Media omitted>\n',
#  'Abhi: Hakeni nodrii\n03/04/2023, 2:40\u202fpm - Abhi: This message was deleted\n03/04/2023, 2:50\u202fpm - Nagaraj Kaddipudi: 7795405465@Naga@Vid@\n08/04/2023, 6:52\u202fpm - Abhi: Zee kannada\nColors Super\ncolors kannada\nStar Suvarna\n09/04/2023, 8:54\u202fam - Nagaraj Kaddipudi: <Media omitted>\n09/04/2023, 8:55\u202fam - Nagaraj Kaddipudi: <Media omitted>\n09/04/2023, 9:12\u202fam - Nagaraj Kaddipudi: <Media omitted>\n09/04/2023, 9:12\u202fam - Nagaraj Kaddipudi: You deleted this message\n',
#  'Abhi: Appaji byad bidrrii\n',
#  'Abhi: Bus ga hokkevi\n11/05/2023, 8:18\u202fpm - Abhi: Appaji petrol Khali agethi 120 hakkri nan acc ge\n11/05/2023, 8:18\u202fpm - Nagaraj Kaddipudi: 👍\n11/05/2023, 8:20\u202fpm - Nagaraj Kaddipudi: Dear SBI User, your A/c X5480-debited by Rs120.0 on 11May23 transfer to ABHISHEK KADDIPUDI Ref No 313137003162. If not done by u, fwd this SMS to 9223008333/Call 1800111109 or 09449112211 to block UPI -SBI\n13/05/2023, 5:36\u202fpm - Nagaraj Kaddipudi: https://youtu.be/IesoBEajfn8\n',
#  'Abhi: <Media omitted>\n16/05/2023, 6:14\u202fpm - Nagaraj Kaddipudi: The Supreme Court yesterday decided to set up a committee to form an All India Tax Payers\' Organization, which would be the largest body in the world.\n\n No government can announce any free electricity, free water, free distribution or loan waivers without the approval of this body, irrespective of which government is ruling.\n Since the money belongs to our tax payers, taxpayers should have the right to monitor its use.\n Political parties keep luring the public by handing out freebies for votes. Whatever projects are announced, the government must first submit their blueprints and get approval from this body. This should also apply to salaries of MPs and MLAs and other non-discretionary benefits received by them.\n Is democracy only limited to voting? What rights do we have as tax payers after that?\n Taxpayers should have the right to hold MPs, MLAs accountable and initiate disciplinary action against them for obstructing the functioning of Parliament. They are paid by taxpayers after all "servants".\n The right to withdraw any such "freebies" should also be implemented soon.\n If you agree, please contact as many people as possible. To do this, share the post.\n Send this to at least 10 of your friends.\n Please share this message to go viral. 🙏\n\n https://www.nationalheraldindia.com/india/sc-forming-panel-to-examine-issue-of-freebies-by-political-parties-is-burial-by-committee-experts\n*A very good news long awaited for.*\n👏👏👏👏👏\n16/05/2023, 6:19\u202fpm - Nagaraj Kaddipudi: <Media omitted>\n16/05/2023, 6:19\u202fpm - Nagaraj Kaddipudi: <Media omitted>\n16/05/2023, 6:55\u202fpm - Abhi: <Media omitted>\n',
#  'Nagaraj Kaddipudi: https://www.ikeabest.shop/products/%E3%80%90buy-1-get-1-free%E3%80%91folding-storage-cabinet%EF%BC%888-10layers%EF%BC%89?fbclid=IwAR1csfqp56tUbLzAky1v-4qJRYhjZy-THKtMawgDYQs__V9aRNnBq_lmSkg_aem_th_ATgn1qc0JLbAX4AiuK-F6uHNu72YBOwTxq0xq__6Qhl1AIjkLPZKpz_LunA0W9FsoYMfe1xr9DJKrCEVOmyrLic7\n22/05/2023, 6:26\u202fpm - Abhi: <Media omitted>\n22/05/2023, 6:27\u202fpm - Abhi: <Media omitted>\n22/05/2023, 6:27\u202fpm - Abhi: <Media omitted>\n',
#  'Abhi: Appaji idli ge sambar thogand barri\n25/05/2023, 6:18\u202fpm - Abhi: 8892304846\n03/06/2023, 7:45\u202fpm - Nagaraj Kaddipudi: <Media omitted>\n07/06/2023, 8:27\u202fpm - Nagaraj Kaddipudi: ಅಭಿ ಕಿರಾಣಿ ಅಂಗಡಿಗೆ ಬಾ\n15/06/2023, 9:04\u202fam - Abhi: https://www.amazon.in/Amazon-Basics-Mobile-Adjustable-Bracket/dp/B0BY2MRXWG/ref=mp_s_a_1_2_sspa?crid=1LCA6DSKD0FS&keywords=phone+holder+for+tripod&qid=1686800035&sprefix=phone+holder+for+tripod%2Caps%2C273&sr=8-2-spons&sp_csd=d2lkZ2V0TmFtZT1zcF9waG9uZV9zZWFyY2hfYXRm&psc=1\n18/06/2023, 8:34\u202fam - Abhi: <Media omitted>\n',
#  'Abhi: This message was deleted\n',
#  'Nagaraj Kaddipudi: OTP for Aadhaar (XX5761) is 818093 (valid for 10 mins). To update Aadhaar, Upload documents on myaadhaar.uidai.gov.in or visit Aadhaar Center. Call 1947 for info. -UIDAI\n',
#  'Abhi: 424347165761\n',
#  'Abhi: 3521433116\n',
#  'Nagaraj Kaddipudi: OTP for Aadhaar (XX5761) is 743584 (valid for 10 mins). To update Aadhaar, Upload documents on myaadhaar.uidai.gov.in or visit Aadhaar Center. Call 1947 for info. -UIDAI\n',
#  'Nagaraj Kaddipudi: OTP for Aadhaar (XX5761) is 686598 (valid for 10 mins). To update Aadhaar, Upload documents on myaadhaar.uidai.gov.in or visit Aadhaar Center. Call 1947 for info. -UIDAI\n',
#  'Nagaraj Kaddipudi: OTP for Aadhaar (XX5761) is 815365 (valid for 10 mins). To update Aadhaar, Upload documents on myaadhaar.uidai.gov.in or visit Aadhaar Center. Call 1947 for info. -UIDAI\n22/06/2023, 1:06\u202fam - Abhi: https://sevasindhugs.karnataka.gov.in/\n22/06/2023, 8:06\u202fam - Nagaraj Kaddipudi: <Media omitted>\n22/06/2023, 8:06\u202fam - Nagaraj Kaddipudi: https://sevasindhugs.karnataka.gov.in/\n25/06/2023, 7:40\u202fpm - Nagaraj Kaddipudi: <Media omitted>\n27/06/2023, 8:41\u202fam - Nagaraj Kaddipudi: <Media omitted>\n27/06/2023, 8:42\u202fam - Nagaraj Kaddipudi: <Media omitted>\n',
#  'Abhi: Elle adiri?\n',
#  'Abhi: Ramesh Kh\n+919620220609\nKarnataka India\nhttps://truecaller.com/search/in/+919620220609\n\nsent using Truecaller\n',
#  'Abhi: <Media omitted>\n']

# %%
date_time = re.findall(pattern,data)
date_time
# Out:
# ['11/07/2022, 12:25\u202fpm - ',
#  '11/07/2022, 12:25\u202fpm - ',
#  '11/07/2022, 12:27\u202fpm - ',
#  '11/07/2022, 12:28\u202fpm - ',
#  '11/07/2022, 12:29\u202fpm - ',
#  '11/07/2022, 12:29\u202fpm - ',
#  '11/07/2022, 12:32\u202fpm - ',
#  '22/07/2022, 11:15\u202fam - ',
#  '29/07/2022, 11:05\u202fam - ',
#  '29/07/2022, 11:13\u202fam - ',
#  '29/07/2022, 11:14\u202fam - ',
#  '29/07/2022, 11:20\u202fam - ',
#  '02/08/2022, 11:11\u202fam - ',
#  '02/08/2022, 11:11\u202fam - ',
#  '03/08/2022, 10:02\u202fam - ',
#  '03/08/2022, 10:02\u202fam - ',
#  '03/08/2022, 11:20\u202fam - ',
#  '03/08/2022, 11:20\u202fam - ',
#  '03/08/2022, 11:20\u202fam - ',
#  '03/08/2022, 11:20\u202fam - ',
#  '03/08/2022, 11:20\u202fam - ',
#  '03/08/2022, 11:20\u202fam - ',
#  '03/08/2022, 11:20\u202fam - ',
#  '03/08/2022, 11:20\u202fam - ',
#  '03/08/2022, 11:20\u202fam - ',
#  '03/08/2022, 11:56\u202fam - ',
#  '03/08/2022, 11:56\u202fam - ',
#  '08/08/2022, 12:46\u202fam - ',
#  '29/08/2022, 10:43\u202fam - ',
#  '23/10/2022, 12:50\u202fpm - ',
#  '09/11/2022, 12:38\u202fpm - ',
#  '09/11/2022, 12:39\u202fpm - ',
#  '11/11/2022, 10:32\u202fam - ',
#  '29/11/2022, 11:20\u202fam - ',
#  '18/12/2022, 10:21\u202fpm - ',
#  '24/12/2022, 12:37\u202fpm - ',
#  '31/12/2022, 10:33\u202fam - ',
#  '03/01/2023, 11:35\u202fpm - ',
#  '03/01/2023, 11:36\u202fpm - ',
#  '03/01/2023, 11:36\u202fpm - ',
#  '03/01/2023, 11:38\u202fpm - ',
#  '03/01/2023, 11:38\u202fpm - ',
#  '03/01/2023, 11:39\u202fpm - ',
#  '03/01/2023, 11:39\u202fpm - ',
#  '12/02/2023, 10:30\u202fam - ',
#  '16/02/2023, 12:31\u202fpm - ',
#  '21/02/2023, 10:30\u202fam - ',
#  '21/02/2023, 10:30\u202fam - ',
#  '21/02/2023, 10:30\u202fam - ',
#  '21/02/2023, 10:30\u202fam - ',
#  '21/02/2023, 10:30\u202fam - ',
#  '21/02/2023, 10:31\u202fam - ',
#  '21/02/2023, 10:31\u202fam - ',
#  '21/02/2023, 10:31\u202fam - ',
#  '21/02/2023, 10:31\u202fam - ',
#  '21/02/2023, 10:31\u202fam - ',
#  '22/02/2023, 11:21\u202fam - ',
#  '23/03/2023, 12:04\u202fpm - ',
#  '09/05/2023, 10:34\u202fam - ',
#  '09/05/2023, 10:34\u202fam - ',
#  '16/05/2023, 10:09\u202fam - ',
#  '22/05/2023, 10:47\u202fam - ',
#  '25/05/2023, 12:06\u202fpm - ',
#  '21/06/2023, 12:25\u202fam - ',
#  '21/06/2023, 11:58\u202fpm - ',
#  '22/06/2023, 12:02\u202fam - ',
#  '22/06/2023, 12:03\u202fam - ',
#  '22/06/2023, 12:19\u202fam - ',
#  '22/06/2023, 12:22\u202fam - ',
#  '22/06/2023, 12:39\u202fam - ',
#  '04/07/2023, 10:11\u202fpm - ',
#  '07/07/2023, 11:47\u202fam - ',
#  '15/07/2023, 10:45\u202fpm - ']

# %%
data_d={"messages":messages[1:],"date":date_time}

# %%
len(messages)
# Out:
# 74

# %%
len(date_time)
# Out:
# 73

# %%
df=pd.DataFrame(data_d)

# %%
df.head()
# Out:
#                                             messages                     date
# 0  Messages and calls are end-to-end encrypted. N...  11/07/2022, 12:25 pm -
# 1                   Nagaraj Kaddipudi: Plz send me\n  11/07/2022, 12:25 pm -
# 2  Nagaraj Kaddipudi: My status 3rd video downloa...  11/07/2022, 12:27 pm -
# 3                          Abhi: 20 best medicine?\n  11/07/2022, 12:28 pm -
# 4                             Nagaraj Kaddipudi: 👍\n  11/07/2022, 12:29 pm -

# %%
pattern=r".*?:\s*"

# %%
df["user"]=df["messages"].apply(lambda x:re.search(pattern,x).group() if re.search(pattern,x) else "group notification" )

# %%
df["user"]=df["user"].apply(lambda x:x.replace(":",""))

# %%
df.head()
# Out:
#                                             messages                     date  \
# 0  Messages and calls are end-to-end encrypted. N...  11/07/2022, 12:25 pm -
# 1                   Nagaraj Kaddipudi: Plz send me\n  11/07/2022, 12:25 pm -
# 2  Nagaraj Kaddipudi: My status 3rd video downloa...  11/07/2022, 12:27 pm -
# 3                          Abhi: 20 best medicine?\n  11/07/2022, 12:28 pm -
# 4                             Nagaraj Kaddipudi: 👍\n  11/07/2022, 12:29 pm -
#
#                  user
# 0  group notification
# 1  Nagaraj Kaddipudi
# 2  Nagaraj Kaddipudi
# 3               Abhi
# 4  Nagaraj Kaddipudi

# %%
df["messages"]=df["messages"].apply(lambda x:re.split(pattern,x))

# %%
df.head()
# Out:
#                                             messages                     date  \
# 0  [Messages and calls are end-to-end encrypted. ...  11/07/2022, 12:25 pm -
# 1                                  [, Plz send me\n]  11/07/2022, 12:25 pm -
# 2     [, My status 3rd video download and send me\n]  11/07/2022, 12:27 pm -
# 3                            [, 20 best medicine?\n]  11/07/2022, 12:28 pm -
# 4                                            [, 👍\n]  11/07/2022, 12:29 pm -
#
#                  user
# 0  group notification
# 1  Nagaraj Kaddipudi
# 2  Nagaraj Kaddipudi
# 3               Abhi
# 4  Nagaraj Kaddipudi

# %%
df["messages"]=df["messages"].apply(lambda x:x[0] if x[0] else x[1])

# %%
df["messages"]=df["messages"].apply(lambda x:x.replace("\n",""))

# %%
df.head(10)
# Out:
#                                             messages                     date  \
# 0  Messages and calls are end-to-end encrypted. N...  11/07/2022, 12:25 pm -
# 1                                        Plz send me  11/07/2022, 12:25 pm -
# 2           My status 3rd video download and send me  11/07/2022, 12:27 pm -
# 3                                  20 best medicine?  11/07/2022, 12:28 pm -
# 4                                                  👍  11/07/2022, 12:29 pm -
# 5                                    <Media omitted>  11/07/2022, 12:29 pm -
# 6                                                  👍  11/07/2022, 12:32 pm -
# 7                                    <Media omitted>  22/07/2022, 11:15 am -
# 8                                Shop now on Meesho!  29/07/2022, 11:05 am -
# 9                                Shop now on Meesho!  29/07/2022, 11:13 am -
#
#                  user
# 0  group notification
# 1  Nagaraj Kaddipudi
# 2  Nagaraj Kaddipudi
# 3               Abhi
# 4  Nagaraj Kaddipudi
# 5               Abhi
# 6  Nagaraj Kaddipudi
# 7               Abhi
# 8  Nagaraj Kaddipudi
# 9  Nagaraj Kaddipudi

# %%
df["message_Date"]=pd.to_datetime(df["date"],format="%m/%d/%y, %H:%M - ")

# %%
df=df.drop("date",axis=1)

# %%
df["hour"]=df.message_Date.dt.hour
df["minute"]=df.message_Date.dt.minute
df["second"]=df.message_Date.dt.second
df["day"]=df.message_Date.dt.day_name()
df["month"]=df.message_Date.dt.month_name()
df["year"]=df.message_Date.dt.year

# %%
df.head(50)
# Out:
#                                         messages                date  \
# 0   Sidil Sharya created group "Billie eilish 😍"  12/18/20, 17:26 -
# 1                                 You were added  12/18/20, 17:26 -
# 2                        Yo guys I need stickers   3/29/22, 23:10 -
# 3      Bought new phone kind'a broke on stickers   3/29/22, 23:10 -
# 4                   Pls send most dirtiest one's   3/29/22, 23:11 -
# 5                                <Media omitted>   3/29/22, 23:11 -
# 6                                <Media omitted>   3/29/22, 23:12 -
# 7                                <Media omitted>   3/29/22, 23:12 -
# 8                                <Media omitted>   3/29/22, 23:12 -
# 9                                <Media omitted>   3/29/22, 23:12 -
# 10                               <Media omitted>   3/29/22, 23:12 -
# 11                               <Media omitted>   3/29/22, 23:12 -
# 12                                             .   3/29/22, 23:12 -
# 13                               <Media omitted>   3/29/22, 23:12 -
# 14                                             ?   3/29/22, 23:12 -
# 15                                        yavddd   3/29/22, 23:12 -
# 16                                        paaaaa   3/29/22, 23:12 -
# 17                                       Iqoo z5   3/29/22, 23:12 -
# 18                                           Enu   3/29/22, 23:12 -
# 19                                            😋😋   3/29/22, 23:12 -
# 20                              Phone name loudu   3/29/22, 23:12 -
# 21                               <Media omitted>   3/29/22, 23:13 -
# 22                               <Media omitted>   3/29/22, 23:13 -
# 23                               <Media omitted>   3/29/22, 23:13 -
# 24                               <Media omitted>   3/29/22, 23:13 -
# 25                               <Media omitted>   3/29/22, 23:13 -
# 26                               <Media omitted>   3/29/22, 23:13 -
# 27                                    Id yavd le   3/29/22, 23:14 -
# %%
hist=pd.DataFrame({"name":name,"no. of messages":number_of_messages})

# %%
def histogram(typ="type",name=name,number=[]):
    h=pd.DataFrame({"name":name,f"number of {typ}": number})
    plt.title(f"Number Of {typ} By Individual Member")
    plt.bar(h["name"],h[f"number of {typ}"],color="purple")
    plt.xlabel("Member")
    plt.ylabel(f"Number of {typ}")
    plt.show()

# %%
import matplotlib.pyplot as plt
plt.title("Number Of Messages By Individual Member")
plt.bar(hist["name"],hist["no. of messages"],color="purple")
plt.xlabel("Member")
plt.ylabel("Number of Messages")
# Out:
# Text(0, 0.5, 'Number of Messages')

# %% [markdown]
# ## League of my own🤩🤩

# %%
hist
# Out:
#        name  no. of messages
# 0  Abhishek             2346
# 1    Roshan             3043

# %%
number_of_stickers=[]
for i in members:
    number_of_stickers.append(len(df[(df["user"]==i)&(df["messages"].str.strip("\u200e")=="sticker omitted")]))

# %%
histogram("stickers sent",name,number_of_stickers)

# %%
sum(number_of_stickers)
# Out:
# 1004

# %% [markdown]
# ## 😎 obviously I am the highest sticker sender

# %%
number_of_delmsg=[]
for i in members:
    number_of_delmsg.append(len(df[(df["user"]==i)&(df["messages"].str.strip("\u200e")=="This message was deleted.")]))

# %%
histogram(" Messages Deleted",name,number_of_delmsg)

# %%
number_of_delmsg
# Out:
# [22, 0]

# %% [markdown]
# ## 💥Roshan never deleted a message

# %%
number_of_image=[]
for i in members:
    number_of_image.append(len(df[(df["user"]==i)&(df["messages"].str.strip("\u200e")=="image omitted")]))

# %%
histogram("Images Sent",name,number_of_image)

# %% [markdown]
# ## 🦾 images - Sharat

# %%
number_of_video=[]
for i in members:
    number_of_video.append(len(df[(df["user"]==i)&(df["messages"].str.strip("\u200e")=="video omitted")]))

# %%
histogram("Video Sent",name,number_of_video)

# %% [markdown]
# ## 😅 ye londe ashleel hai {Roshan,Sharat}

# %%
number_of_f=[]
for i in members:
    number_of_f.append(len(df[(df["user"]==i)&(df["messages"].str.contains("fuck",case=False))]))

# %%
histogram("Fucks Sent",name,number_of_f)

# %%
sum(number_of_f)
# Out:
# 2

# %% [markdown]
# ## Evenly matched 🤔  impossible Roshan == snail 🤐

# %%
number_of_h=[]
for i in members:
    number_of_h.append(len(df[(df["user"]==i)&(df["messages"].str.contains(r"hattr|hatr|hattrr|hatru|hatrr",case=False))]))

# %%
histogram("Hattrr sent",name,number_of_h)

# %%
sum(number_of_h)
# Out:
# 10

# %% [markdown]
# ## 😂😂😂 Hattr ninga ( snail has some because we changed group name a lot of time to hattrr)

# %%
number_of_bsdk=[]
for i in members:
    number_of_bsdk.append(len(df[(df["user"]==i)&(df["messages"].str.contains(r"bsdk|bosdike|bosdi",case=False))]))

# %%
number_of_bsdk
# Out:
# [19, 3]

# %%
histogram("BSDK sent",name,number_of_bsdk)

# %%
number_of_bsdk
# Out:
# [19, 3]

# %%
sum(number_of_bsdk)
# Out:
# 22

# %% [markdown]
# ## no comments

# %%
words=[]
for i in df["messages"]:
    words.extend(i.strip("\u200e").split())

# %%
item=['sticker','omitted','image','This',
 'message',
 'was',
 'deleted.','video']

# %%
words=list(filter(lambda x: x not in item, words))

# %%
len(words)
# Out:
# 11598

# %% [markdown]
# ## number of words used in our chat 49900

# %%
def histogram(typ="type",name=name,number=[]):
    h=pd.DataFrame({"name":name,f"number of {typ}": number})
   
    plt.title(f"{typ}")
    plt.barh(h["name"],h[f"number of {typ}"],color="purple")
    
    plt.ylabel("Words")
    plt.xlabel(f"Number of {typ}")
    for index, value in enumerate(h[f"number of {typ}"]):
        plt.text(value, index,
                 str(value))
    plt.show()

# %%
from collections import Counter
wd=Counter(words).most_common(10)

# %%
wd
# Out:
# [('le', 670),
#  ('Ha', 231),
#  ('Le', 218),
#  ('Hu', 146),
#  ('\u200edocument', 110),
#  ('😂', 92),
#  ('•', 75),
#  ('yen', 67),
#  ('pa', 65),
#  ('pages', 63)]

# %%
name=[]
value=[]
for i in wd:
    name.append(i[0])
    value.append(i[1])

# %%
histogram(" Most Common Words Used",name,value)

# %% [markdown]
# ## World Cloud

# %%
from wordcloud import WordCloud

# %%
messagess=df["messages"]

# %%
messagess
# Out:
# 0       ‎Messages and calls are end-to-end encrypted. ...
# 1                                                  Party🥳
# 2                                                  😃ha ha
# 3                                      Abhya cpp heli kod
# 4                                                   Ha le
#                               ...
# 5367                             sudo apt-get install gcc
# 5368                                           Path mat??
# 5369                    Install mada set agila andr nodan
# 5370                                                  Ha‎
# 5371        WhatsApp Chat - 🐌 snail.zip ‎document omitted
# Name: messages, Length: 5372, dtype: object

# %%
word_string = ' '.join(words)

# %%
wc=WordCloud(width=1000,height=1000,min_font_size=10,background_color="white")
wc_gene=wc.generate(word_string)

# %%
plt.imshow(wc_gene)

# %% [markdown]
# ## emoji used

# %%
# !pip install emoji==1.6.3
# Out:
# Collecting emoji==1.6.3
#   Downloading emoji-1.6.3.tar.gz (174 kB)
#                                               0.0/174.2 kB ? eta -:--:--
#      ----------------                        71.7/174.2 kB 1.3 MB/s eta 0:00:01
#      -------------------------------------- 174.2/174.2 kB 1.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: emoji
#   Building wheel for emoji (setup.py): started
#   Building wheel for emoji (setup.py): finished with status 'done'
#   Created wheel for emoji: filename=emoji-1.6.3-py3-none-any.whl size=170306 sha256=a58702e8d3c9234379c6c7f1a16554d1dfbe9c545d3d2541c0e55ae5a9dabd6f
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\83\42\4a\2e5a7b28b80e3a4f143cb5bbfcfbfe54958ccb533bb8ce2a99
# Successfully built emoji
# Installing collected packages: emoji
#   Attempting uninstall: emoji
#     Found existing installation: emoji 1.7.0
#     Uninstalling emoji-1.7.0:
#       Successfully uninstalled emoji-1.7.0
# Successfully installed emoji-1.6.3

# %%
import emoji

# %%
word=df["messages"][3]

# %%
emojis=[]
for i in df["messages"]:
    for c in i:
        if emoji.is_emoji(c):
            emojis.extend(c)

# %%
emoji_count=Counter(emojis).most_common(5)

# %% [markdown]
# ## total

# %%
import matplotlib.pyplot as plt
import emoji

def create_pie_chart(labels, sizes):
    labels_with_names = [emoji.demojize(label)[1:] for label in labels]
    

    plt.figure(figsize=(5, 5)) 
    wedges, _, _ = plt.pie(sizes, labels=labels_with_names, autopct='%1.1f%%', startangle=140)
    

    plt.title('Pie Chart')

    for i, wedge in enumerate(wedges):
        angle = (wedge.theta2 - wedge.theta1) / 2.0 + wedge.theta1
        x = wedge.r * 0.7 * np.cos(np.deg2rad(angle))
        y = wedge.r * 0.7 * np.sin(np.deg2rad(angle))
        plt.text(x, y, labels[i], ha='center', va='center', fontsize=12)  # Adjust font size as needed
    
    plt.axis('equal')
    
    plt.xticks([])
    plt.yticks([])
    
    plt.show()

# %%
e
# Out:
#    0     1
# 0  😂  2166
# 1  🤣  1575
# 2  🔥   319
# 3  🥳   300
# 4  ✌   222

# %%
create_pie_chart(e[0],e[1])

# %% [markdown]
# ## 😂 is used more then 🤣

# %% [markdown]
# ## time series

# %%
df["year"]=df.message_Date.dt.year

# %%
timeline=df.groupby(["year","month"]).count()["messages"].reset_index()

# %%
time=[]
for i in range(timeline.shape[0]):
    time.append(timeline["month"][i]+"-"+str(timeline["year"][i]))

# %%
timeline["time"]=time

# %%
timeline
# Out:
#     year      month  messages            time
# 0   2020      April       129      April-2020
# 1   2020     August       652     August-2020
# 2   2020   December       513   December-2020
# 3   2020       July       744       July-2020
# 4   2020       June      1268       June-2020
# 5   2020        May       171        May-2020
# 6   2020   November      1349   November-2020
# 7   2020    October       518    October-2020
# 8   2020  September      1047  September-2020
# 9   2021      April       771      April-2021
# 10  2021     August       648     August-2021
# 11  2021   December       124   December-2021
# 12  2021   February       221   February-2021
# 13  2021    January       417    January-2021
# 14  2021       July       512       July-2021
# 15  2021       June       618       June-2021
# 16  2021      March       562      March-2021
# 17  2021        May       777        May-2021
# 18  2021   November       142   November-2021
# 19  2021    October       258    October-2021
# 20  2021  September       720  September-2021
# 21  2022      April       256      April-2022
# 22  2022     August        80     August-2022
# 23  2022   December       418   December-2022
# 24  2022   February        39   February-2022
# 25  2022    January        43    January-2022
# 26  2022       July        52       July-2022
# 27  2022       June       238       June-2022
# 28  2022      March        82      March-2022
# 29  2022        May       539        May-2022
# 30  2022   November       206   November-2022
# 31  2022    October       472    October-2022
# 32  2022  September       107  September-2022
# 33  2023      April       644      April-2023
# 34  2023   February        61   February-2023
# 35  2023    January        51    January-2023
# 36  2023       July       222       July-2023
# 37  2023       June       778       June-2023
# 38  2023      March       599      March-2023
# 39  2023        May      1104        May-2023

# %%
plt.figure(figsize=(8,8))
plt.plot(timeline["time"],timeline["messages"],)
plt.xticks(rotation="vertical")
plt.show()

# %% [markdown]
# ## july - 2020 november - 2020 and may 2023 shows highest engagement in group

# %% [markdown]
# ### weekdays

# %%
day_timeline=df["day"].value_counts()

# %%
# Out:
# 'Tuesday'

# %%
histogram(" messages",day_timeline.keys(),day_timeline)

# %%
def histogram(typ="type",name=name,number=[]):
    h=pd.DataFrame({"name":name,f"number of {typ}": number})
   
    plt.title(f"{typ}")
    plt.barh(h["name"],h[f"number of {typ}"],color="purple")
    
    plt.ylabel("Words")
    plt.xlabel(f"Number of {typ}")
    for index, value in enumerate(h[f"number of {typ}"]):
        plt.text(value, index,
                 str(value))
    plt.show()

# %%
df.to_csv("preprocessed_chat.csv")
