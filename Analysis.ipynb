# %%
import re
import pandas as pd

# %%
f=open("_chat.txt","r",encoding="utf-8")

# %%
data=f.read()

# %%
data
# Out:
# '[18/04/20, 11:04:22 PM] 🐌 snail: \u200eMessages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them.\n[18/04/20, 11:04:20 PM] Sharat: \u200eSharat created group “hanga erli”\n[18/04/20, 11:04:21 PM] 🐌 snail: \u200eSharat added you\n[18/04/20, 11:04:56 PM] Baganna: \u200eBaganna changed the subject to “Agethi😉”\n[18/04/20, 11:05:36 PM] Baganna: Yak pa e group?\n[18/04/20, 11:08:06 PM] Sharat: yenena kalasaka\n[18/04/20, 11:08:18 PM] Baganna: Nk na add mad\n[18/04/20, 11:08:26 PM] Sharat: adana\n[18/04/20, 11:09:00 PM] Baganna: Ella\n[18/04/20, 11:09:25 PM] Sharat: add madak baravald\n[18/04/20, 11:10:45 PM] Baganna: Admin mad nanga\n[18/04/20, 11:10:52 PM] NK 🐂: \u200eNK 🐂 joined using this group\'s invite link\n\u200e[18/04/20, 11:17:47 PM] Sharat: \u200eimage omitted\n[18/04/20, 11:18:23 PM] NK 🐂: Mansik na add madrii le\n[18/04/20, 11:19:17 PM] Rohit: \u200eSharat added Rohit\n[18/04/20, 11:21:19 PM] Rohit: Ageti\n\u200e[1
# ...

# %%
pattern=r"\[\d{1,2}/\d{1,2}/\d{1,2}, \d{1,2}:\d{1,2}:\d{1,2} [AP]M\]"

# %%
messages = re.split(pattern,data)

# %%
messages[1:]
# Out:
# [' 🐌 snail: \u200eMessages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them.\n',
#  ' Sharat: \u200eSharat created group “hanga erli”\n',
#  ' 🐌 snail: \u200eSharat added you\n',
#  ' Baganna: \u200eBaganna changed the subject to “Agethi😉”\n',
#  ' Baganna: Yak pa e group?\n',
#  ' Sharat: yenena kalasaka\n',
#  ' Baganna: Nk na add mad\n',
#  ' Sharat: adana\n',
#  ' Baganna: Ella\n',
#  ' Sharat: add madak baravald\n',
#  ' Baganna: Admin mad nanga\n',
#  " NK 🐂: \u200eNK 🐂 joined using this group's invite link\n\u200e",
#  ' Sharat: \u200eimage omitted\n',
#  ' NK 🐂: Mansik na add madrii le\n',
#  ' Rohit: \u200eSharat added Rohit\n',
#  ' Rohit: Ageti\n\u200e',
#  ' Rohit: \u200esticker omitted\n\u200e',
#  ' Baganna: \u200esticker omitted\n\u200e',
#  ' Rohit: \u200esticker omitted\n\u200e',
#  ' Baganna: \u200esticker omitted\n\u200e',
#  ' Baganna: \u200esticker omitted\n',
# ...

# %%
date_time = re.findall(pattern,data)

# %%
date_time
# Out:
# ['[18/04/20, 11:04:22 PM]',
#  '[18/04/20, 11:04:20 PM]',
#  '[18/04/20, 11:04:21 PM]',
#  '[18/04/20, 11:04:56 PM]',
#  '[18/04/20, 11:05:36 PM]',
#  '[18/04/20, 11:08:06 PM]',
#  '[18/04/20, 11:08:18 PM]',
#  '[18/04/20, 11:08:26 PM]',
#  '[18/04/20, 11:09:00 PM]',
#  '[18/04/20, 11:09:25 PM]',
#  '[18/04/20, 11:10:45 PM]',
#  '[18/04/20, 11:10:52 PM]',
#  '[18/04/20, 11:17:47 PM]',
#  '[18/04/20, 11:18:23 PM]',
#  '[18/04/20, 11:19:17 PM]',
#  '[18/04/20, 11:21:19 PM]',
#  '[18/04/20, 11:21:25 PM]',
#  '[18/04/20, 11:21:36 PM]',
#  '[18/04/20, 11:22:01 PM]',
#  '[18/04/20, 11:22:29 PM]',
#  '[18/04/20, 11:22:45 PM]',
#  '[18/04/20, 11:24:38 PM]',
#  '[18/04/20, 11:24:48 PM]',
#  '[18/04/20, 11:24:58 PM]',
#  '[18/04/20, 11:24:59 PM]',
#  '[18/04/20, 11:25:27 PM]',
#  '[18/04/20, 11:25:34 PM]',
#  '[18/04/20, 11:25:46 PM]',
#  '[18/04/20, 11:25:48 PM]',
#  '[18/04/20, 11:25:51 PM]',
#  '[18/04/20, 11:26:17 PM]',
#  '[18/04/20, 11:26:22 PM]',
#  '[18/04/20, 11:26:24 PM]',
# ...

# %%
data_d={"messages":messages[1:],"date":date_time}

# %%
len(messages)
# Out:
# 18154

# %%
len(date_time)
# Out:
# 18153

# %%
df=pd.DataFrame(data_d)

# %%
df
# Out:
#                                                 messages  \
# 0       🐌 snail: ‎Messages and calls are end-to-end e...
# 1           Sharat: ‎Sharat created group “hanga erli”\n
# 2                           🐌 snail: ‎Sharat added you\n
# 3       Baganna: ‎Baganna changed the subject to “Age...
# 4                             Baganna: Yak pa e group?\n
# ...                                                  ...
# 18148   Baganna: Is thier any easy way to check that ?\n
# 18149               NK 🐂: Export maad le without media\n
# 18150                     NK 🐂: Size enn sannad erutha\n
# 18151                                     Roshan: Wait\n
# 18152                                     NK 🐂: In kbs\n
#
#                           date
# 0      [18/04/20, 11:04:22 PM]
# 1      [18/04/20, 11:04:20 PM]
# 2      [18/04/20, 11:04:21 PM]
# 3      [18/04/20, 11:04:56 PM]
# 4      [18/04/20, 11:05:36 PM]
# ...                        ...
# 18148   [19/07/23, 5:43:16 PM]
# ...

# %%
for i in df["messages"]:
    result=re.search(pattern,i)
    if result:
        extracted_part = result.group()
        print(extracted_part)
    else:
        print("No match found.")
# Out:
#  🐌 snail:
#  Sharat:
#  🐌 snail:
#  Baganna:
#  Baganna:
#  Sharat:
#  Baganna:
#  Sharat:
#  Baganna:
#  Sharat:
#  Baganna:
#  NK 🐂:
#  Sharat:
#  NK 🐂:
#  Rohit:
#  Rohit:
#  Rohit:
#  Baganna:
#  Rohit:
#  Baganna:
#  Baganna:
#  Rohit:
#  Rohit:
#  Baganna:
#  Rohit:
#  Baganna:
#  NK 🐂:
#  Rohit:
#  Rohit:
#  Rohit:
#  NK 🐂:
#  Rohit:
#  Rohit:
#  Rohit:
#  Rohit:
#  Rohit:
#  Rohit:
#  Rohit:
#  Rohit:
#  Rohit:
#  Rohit:
#  Rohit:
#  Baganna:
#  Baganna:
#  Rohit:
#  Rohit:
#  Rohit:
#  Baganna:
#  Rohit:
#  Rohit:
#  Rohit:
#  Baganna:
#  NK 🐂:
#  NK 🐂:
#  Rohit:
#  NK 🐂:
#  Rohit:
#  Baganna:
#  Rohit:
#  Baganna:
#  Baganna:
#  NK 🐂:
#  Baganna:
#  Rohit:
#  Rohit:
#  Rohit:
#  NK 🐂:
#  Rohit:
#  Rohit:
#  Baganna:
#  Rohit:
#  Rohit:
#  Rohit:
#  Baganna:
#  NK 🐂:
#  Rohit:
#  Rohit:
#  Baganna:
#  Rohit:
#  Baganna:
#  Baganna:
#  Rohit:
#  Rohit:
#  Rohit:
#  NK 🐂:
#  Baganna:
#  Rohit:
#  Rohit:
#  Rohit:
#  Baganna:
#  Baganna:
#  Baganna:
#  NK 🐂:
#  Baganna:
# ...

# %%
df["user"]=df["messages"].apply(lambda x:re.search(pattern,x).group() if re.search(pattern,x) else "group notification" )

# %%
df["user"]=df["user"].apply(lambda x:x.replace(":",""))

# %%
df["user"]=df["user"].apply(lambda x:"Vinayak" if x=="vinayak" else x )

# %%
df["user"].unique()
# Out:
# array(['🐌 snail', 'Sharat', 'Vinayak', 'NK 🐂', 'Rohit', 'Roshan',
#        '\u200eYou'], dtype=object)

# %%
df=df.drop(df[df['user'] == '\u200eYou'].index)

# %%
df.head(20)
# Out:
#                                              messages  \
# 0    🐌 snail: ‎Messages and calls are end-to-end e...
# 1        Sharat: ‎Sharat created group “hanga erli”\n
# 2                        🐌 snail: ‎Sharat added you\n
# 3    Baganna: ‎Baganna changed the subject to “Age...
# 4                          Baganna: Yak pa e group?\n
# 5                           Sharat: yenena kalasaka\n
# 6                            Baganna: Nk na add mad\n
# 7                                     Sharat: adana\n
# 8                                     Baganna: Ella\n
# 9                        Sharat: add madak baravald\n
# 10                         Baganna: Admin mad nanga\n
# 11   NK 🐂: ‎NK 🐂 joined using this group's invite ...
# 12                           Sharat: ‎image omitted\n
# 13                    NK 🐂: Mansik na add madrii le\n
# 14                       Rohit: ‎Sharat added Rohit\n
# 15                                    Rohit: Ageti\n‎
# ...

# %%
df["user"]=df["user"].apply(lambda x:"Abhishek 🐂" if x=="NK 🐂" else x )

# %%
df["user"]=df["user"].apply(lambda x:"Vinayak 👩" if x=="Vinayak" else x )

# %%
df["user"]=df["user"].apply(lambda x:"Roshan 🍗" if x=="Roshan" else x )

# %%
df["user"]=df["user"].apply(lambda x:"Sharat 🔞" if x=="Sharat" else x )

# %%
df["user"]=df["user"].apply(lambda x:"Rohit 💃" if x=="Rohit" else x )

# %%
df["messages"]=df["messages"].apply(lambda x:re.split(pattern,x))

# %%
df["messages"]=df["messages"].apply(lambda x:x[1])

# %%
df["messages"]=df["messages"].apply(lambda x:x.replace("\n",""))

# %%
df.head(10)
# Out:
#                                             messages                     date  \
# 0  ‎Messages and calls are end-to-end encrypted. ...  [18/04/20, 11:04:22 PM]
# 1                 ‎Sharat created group “hanga erli”  [18/04/20, 11:04:20 PM]
# 2                                  ‎Sharat added you  [18/04/20, 11:04:21 PM]
# 3          ‎Baganna changed the subject to “Agethi😉”  [18/04/20, 11:04:56 PM]
# 4                                    Yak pa e group?  [18/04/20, 11:05:36 PM]
# 5                                    yenena kalasaka  [18/04/20, 11:08:06 PM]
# 6                                      Nk na add mad  [18/04/20, 11:08:18 PM]
# 7                                              adana  [18/04/20, 11:08:26 PM]
# 8                                               Ella  [18/04/20, 11:09:00 PM]
# 9                                 add madak baravald  [18/04/20, 11:09:25 PM]
#
#         user
# 0    🐌 snail
# 1   Sharat 🔞
# 2    🐌 snail
# 3  Vinayak 👩
# 4  Vinayak 👩
# 5   Sharat 🔞
# ...

# %%
df["date"]=df["date"].apply(lambda x:x.replace("[",""))

# %%
df["date"]=df["date"].apply(lambda x:x.replace("]",""))

# %%
df
# Out:
#                                                 messages  \
# 0      ‎Messages and calls are end-to-end encrypted. ...
# 1                     ‎Sharat created group “hanga erli”
# 2                                      ‎Sharat added you
# 3              ‎Baganna changed the subject to “Agethi😉”
# 4                                        Yak pa e group?
# ...                                                  ...
# 18148              Is thier any easy way to check that ?
# 18149                       Export maad le without media
# 18150                             Size enn sannad erutha
# 18151                                               Wait
# 18152                                             In kbs
#
#                         date        user
# 0      18/04/20, 11:04:22 PM     🐌 snail
# 1      18/04/20, 11:04:20 PM    Sharat 🔞
# 2      18/04/20, 11:04:21 PM     🐌 snail
# 3      18/04/20, 11:04:56 PM   Vinayak 👩
# 4      18/04/20, 11:05:36 PM   Vinayak 👩
# ...

# %%
df["message_Date"]=pd.to_datetime(df["date"],format="%d/%m/%y, %I:%M:%S %p")

# %%
df=df.drop("date",axis=1)

# %%
df["hour"]=df.message_Date.dt.hour

# %%
df["minute"]=df.message_Date.dt.minute
df["second"]=df.message_Date.dt.second
df["day"]=df.message_Date.dt.day_name()
df["month"]=df.message_Date.dt.month_name()

# %%
df.head(50)
# Out:
#                                              messages        user  \
# 0   ‎Messages and calls are end-to-end encrypted. ...     🐌 snail
# 1                  ‎Sharat created group “hanga erli”    Sharat 🔞
# 2                                   ‎Sharat added you     🐌 snail
# 3           ‎Baganna changed the subject to “Agethi😉”   Vinayak 👩
# 4                                     Yak pa e group?   Vinayak 👩
# 5                                     yenena kalasaka    Sharat 🔞
# 6                                       Nk na add mad   Vinayak 👩
# 7                                               adana    Sharat 🔞
# 8                                                Ella   Vinayak 👩
# 9                                  add madak baravald    Sharat 🔞
# 10                                    Admin mad nanga   Vinayak 👩
# 11       ‎NK 🐂 joined using this group's invite link‎  Abhishek 🐂
# 12                                     ‎image omitted    Sharat 🔞
# ...

# %%
members=df["user"].unique()

# %%
name=[]
number_of_messages=[]
for i in members:
    name.append(i)
    number_of_messages.append(len(df[df["user"]==i]))

# %%
name,number_of_messages
# Out:
# (['🐌 snail', 'Sharat 🔞', 'Vinayak 👩', 'Abhishek 🐂', 'Rohit 💃', 'Roshan 🍗'],
#  [23, 3490, 2377, 5917, 4251, 2094])

# %%
hist=pd.DataFrame({"name":name,"no. of messages":number_of_messages})

# %%
def histogram(typ="type",name=name,number=[]):
    h=pd.DataFrame({"name":name,f"number of {typ}": number})
    plt.title(f"Number Of {typ} By Individual Member")
    plt.bar(h["name"],h[f"number of {typ}"],color="purple")
    plt.xlabel("Member")
    plt.ylabel(f"Number of {typ}")
    plt.show()

# %%
import matplotlib.pyplot as plt
plt.title("Number Of Messages By Individual Member")
plt.bar(hist["name"],hist["no. of messages"],color="purple")
plt.xlabel("Member")
plt.ylabel("Number of Messages")
# Out:
# Text(0, 0.5, 'Number of Messages')

# %% [markdown]
# ## League of my own🤩🤩

# %%
hist
# Out:
#          name  no. of messages
# 0     🐌 snail               23
# 1    Sharat 🔞             3490
# 2   Vinayak 👩             2377
# 3  Abhishek 🐂             5917
# 4     Rohit 💃             4251
# 5    Roshan 🍗             2094

# %%
number_of_stickers=[]
for i in members:
    number_of_stickers.append(len(df[(df["user"]==i)&(df["messages"].str.strip("\u200e")=="sticker omitted")]))

# %%
histogram("stickers sent",name,number_of_stickers)

# %% [markdown]
# ## 😎 obviously I am the highest sticker sender

# %%
number_of_delmsg=[]
for i in members:
    number_of_delmsg.append(len(df[(df["user"]==i)&(df["messages"].str.strip("\u200e")=="This message was deleted.")]))

# %%
histogram(" Messages Deleted",name,number_of_delmsg)

# %% [markdown]
# ## 💥Roshan never deleted a message

# %%
number_of_image=[]
for i in members:
    number_of_image.append(len(df[(df["user"]==i)&(df["messages"].str.strip("\u200e")=="image omitted")]))

# %%
histogram("Images Sent",name,number_of_image)

# %% [markdown]
# ## 🦾 images - Sharat

# %%
number_of_video=[]
for i in members:
    number_of_video.append(len(df[(df["user"]==i)&(df["messages"].str.strip("\u200e")=="video omitted")]))

# %%
histogram("Video Sent",name,number_of_video)

# %% [markdown]
# ## 😅 ye londe ashleel hai {Roshan,Sharat}

# %%
number_of_f=[]
for i in members:
    number_of_f.append(len(df[(df["user"]==i)&(df["messages"].str.contains("fuck",case=False))]))

# %%
histogram("Fucks Sent",name,number_of_f)

# %%
sum(number_of_f)
# Out:
# 66

# %% [markdown]
# ## Evenly matched 🤔  impossible Roshan == snail 🤐

# %%
number_of_h=[]
for i in members:
    number_of_h.append(len(df[(df["user"]==i)&(df["messages"].str.contains(r"hattr|hatr|hattrr|hatru|hatrr",case=False))]))

# %%
histogram("Hattrr sent",name,number_of_h)

# %%
sum(number_of_h)
# Out:
# 64

# %% [markdown]
# ## 😂😂😂 Hattr ninga ( snail has some because we changed group name a lot of time to hattrr)

# %%
number_of_bsdk=[]
for i in members:
    number_of_bsdk.append(len(df[(df["user"]==i)&(df["messages"].str.contains(r"bsdk|bosdike|bosdi",case=False))]))

# %%
number_of_bsdk
# Out:
# [0, 5, 20, 122, 34, 17]

# %%
histogram("BSDK sent",name,number_of_bsdk)

# %%
number_of_bsdk
# Out:
# [0, 5, 20, 122, 34, 17]

# %%
sum(number_of_bsdk)
# Out:
# 198

# %% [markdown]
# ## no comments

# %%
words=[]
for i in df["messages"]:
    words.extend(i.strip("\u200e").split())

# %%
item=['sticker','omitted','image','This',
 'message',
 'was',
 'deleted.','video']

# %%
words=list(filter(lambda x: x not in item, words))

# %%
len(words)
# Out:
# 49900

# %% [markdown]
# ## number of words used in our chat 49900

# %%
def histogram(typ="type",name=name,number=[]):
    h=pd.DataFrame({"name":name,f"number of {typ}": number})
   
    plt.title(f"{typ}")
    plt.barh(h["name"],h[f"number of {typ}"],color="purple")
    
    plt.ylabel("Words")
    plt.xlabel(f"Number of {typ}")
    for index, value in enumerate(h[f"number of {typ}"]):
        plt.text(value, index,
                 str(value))
    plt.show()

# %%
from collections import Counter
wd=Counter(words).most_common(10)

# %%
wd
# Out:
# [('le', 1293),
#  ('😂', 808),
#  ('🤣', 365),
#  ('to', 295),
#  ('the', 289),
#  ('pa', 263),
#  ('is', 214),
#  ('ella', 192),
#  ('I', 178),
#  ('for', 164)]

# %%
name=[]
value=[]
for i in wd:
    name.append(i[0])
    value.append(i[1])

# %%
histogram(" Most Common Words Used",name,value)

# %% [markdown]
# ## World Cloud

# %%
from wordcloud import WordCloud

# %%
messagess=df["messages"]

# %%
messagess
# Out:
# 0        ‎Messages and calls are end-to-end encrypted. ...
# 1                       ‎Sharat created group “hanga erli”
# 2                                        ‎Sharat added you
# 3                ‎Baganna changed the subject to “Agethi😉”
# 4                                          Yak pa e group?
#                                ...
# 18148                Is thier any easy way to check that ?
# 18149                         Export maad le without media
# 18150                               Size enn sannad erutha
# 18151                                                 Wait
# 18152                                               In kbs
# Name: messages, Length: 18152, dtype: object

# %%
word_string = ' '.join(words)

# %%
wc=WordCloud(width=1000,height=1000,min_font_size=10,background_color="white")
wc_gene=wc.generate(word_string)

# %%
plt.imshow(wc_gene)

# %% [markdown]
# ## emoji used

# %%
# !pip install emoji==1.6.3
# Out:
# ...
#                                               0.0/174.2 kB ? eta -:--:--
#      ----------------                        71.7/174.2 kB 1.3 MB/s eta 0:00:01
#      -------------------------------------- 174.2/174.2 kB 1.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for emoji: filename=emoji-1.6.3-py3-none-any.whl size=170306 sha256=a58702e8d3c9234379c6c7f1a16554d1dfbe9c545d3d2541c0e55ae5a9dabd6f
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\83\42\4a\2e5a7b28b80e3a4f143cb5bbfcfbfe54958ccb533bb8ce2a99
# Successfully built emoji
# ...
#   Attempting uninstall: emoji
#     Found existing installation: emoji 1.7.0
#     Uninstalling emoji-1.7.0:
#       Successfully uninstalled emoji-1.7.0
# ...

# %%
import emoji

# %%
word=df["messages"][3]

# %%
emojis=[]
for i in df["messages"]:
    for c in i:
        if emoji.is_emoji(c):
            emojis.extend(c)

# %%
emoji_count=Counter(emojis).most_common(5)

# %% [markdown]
# ## total

# %%
import matplotlib.pyplot as plt
import emoji

def create_pie_chart(labels, sizes):
    labels_with_names = [emoji.demojize(label)[1:] for label in labels]
    

    plt.figure(figsize=(5, 5)) 
    wedges, _, _ = plt.pie(sizes, labels=labels_with_names, autopct='%1.1f%%', startangle=140)
    

    plt.title('Pie Chart')

    for i, wedge in enumerate(wedges):
        angle = (wedge.theta2 - wedge.theta1) / 2.0 + wedge.theta1
        x = wedge.r * 0.7 * np.cos(np.deg2rad(angle))
        y = wedge.r * 0.7 * np.sin(np.deg2rad(angle))
        plt.text(x, y, labels[i], ha='center', va='center', fontsize=12)  # Adjust font size as needed
    
    plt.axis('equal')
    
    plt.xticks([])
    plt.yticks([])
    
    plt.show()

# %%
e
# Out:
#    0     1
# 0  😂  2166
# 1  🤣  1575
# 2  🔥   319
# 3  🥳   300
# 4  ✌   222

# %%
create_pie_chart(e[0],e[1])

# %% [markdown]
# ## 😂 is used more then 🤣

# %% [markdown]
# ## time series

# %%
df["year"]=df.message_Date.dt.year

# %%
timeline=df.groupby(["year","month"]).count()["messages"].reset_index()

# %%
time=[]
for i in range(timeline.shape[0]):
    time.append(timeline["month"][i]+"-"+str(timeline["year"][i]))

# %%
timeline["time"]=time

# %%
timeline
# Out:
#     year      month  messages            time
# 0   2020      April       129      April-2020
# 1   2020     August       652     August-2020
# 2   2020   December       513   December-2020
# 3   2020       July       744       July-2020
# 4   2020       June      1268       June-2020
# 5   2020        May       171        May-2020
# 6   2020   November      1349   November-2020
# 7   2020    October       518    October-2020
# 8   2020  September      1047  September-2020
# 9   2021      April       771      April-2021
# 10  2021     August       648     August-2021
# 11  2021   December       124   December-2021
# 12  2021   February       221   February-2021
# 13  2021    January       417    January-2021
# 14  2021       July       512       July-2021
# 15  2021       June       618       June-2021
# 16  2021      March       562      March-2021
# 17  2021        May       777        May-2021
# 18  2021   November       142   November-2021
# ...

# %%
plt.figure(figsize=(8,8))
plt.plot(timeline["time"],timeline["messages"],)
plt.xticks(rotation="vertical")
plt.show()

# %% [markdown]
# ## july - 2020 november - 2020 and may 2023 shows highest engagement in group

# %% [markdown]
# ### weekdays

# %%
day_timeline=df["day"].value_counts()

# %%
# Out:
# 'Tuesday'

# %%
histogram(" messages",day_timeline.keys(),day_timeline)

# %%
def histogram(typ="type",name=name,number=[]):
    h=pd.DataFrame({"name":name,f"number of {typ}": number})
   
    plt.title(f"{typ}")
    plt.barh(h["name"],h[f"number of {typ}"],color="purple")
    
    plt.ylabel("Words")
    plt.xlabel(f"Number of {typ}")
    for index, value in enumerate(h[f"number of {typ}"]):
        plt.text(value, index,
                 str(value))
    plt.show()

# %%
df.to_csv("preprocessed_chat.csv")
